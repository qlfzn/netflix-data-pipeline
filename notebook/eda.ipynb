# %%
import pandas as pd
import os

source_path = "../data/"

dataframes = {}

for file in os.listdir(source_path):
    name = file.split(".")[0]
    ext = file.split(".")[1]

    if ext != "csv":
        continue

    df= pd.read_csv(source_path+file)
    dataframes[name] = df

    print(f"\nDataframe {name} successfully created")
    print(f"Created with {df.shape[0]} rows & {df.shape[1]} columns")
# Out:
# Dataframe recommendation_logs successfully created
# Created with 52000 rows & 11 columns
#
# Dataframe reviews successfully created
# Created with 15450 rows & 12 columns
#
# Dataframe users successfully created
# Created with 10300 rows & 16 columns
#
# Dataframe test successfully created
# Created with 0 rows & 4 columns
#
# Dataframe watch_history successfully created
# Created with 105000 rows & 12 columns
#
# Dataframe movies successfully created
# Created with 1040 rows & 18 columns
#
# Dataframe search_logs successfully created
# Created with 26500 rows & 11 columns

# %%
# check columns
for name, df in dataframes.items():
    print(f"\n--{name}--\n", df.dtypes)
# Out:
# --recommendation_logs--
#  recommendation_id        object
# user_id                  object
# movie_id                 object
# recommendation_date      object
# recommendation_type      object
# recommendation_score    float64
# was_clicked                bool
# position_in_list          int64
# device_type              object
# time_of_day              object
# algorithm_version        object
# dtype: object
#
# --reviews--
#  review_id             object
# user_id               object
# movie_id              object
# rating                 int64
# review_date           object
# device_type           object
# is_verified_watch       bool
# helpful_votes        float64
# total_votes          float64
# review_text           object
# sentiment             object
# sentiment_score      float64
# dtype: object
#
# --users--
#  user_id                     object
# email                       object
# first_name                  object
# last_name                   object
# ...

# %%
dataframes["users"].sample(10)
# Out:
#          user_id                        email first_name  last_name   age  \
# 6688  user_06689   justinthompson@example.org      Linda     Torres  35.0
# 7042  user_07043       trodriguez@example.com      Vicki      Mason  28.0
# 1576  user_01577       pfernandez@example.org      James        Lee   NaN
# 4461  user_04462  gregoryanderson@example.org       Sean    Clayton  41.0
# 410   user_00411          ntorres@example.net     Yvette     Ibarra   NaN
# 8284  user_08285  macdonaldsandra@example.net       Adam       Neal  44.0
# 1611  user_01612           tavery@example.com    Madison      Nunez  21.0
# 8506  user_08507         ueverett@example.com    Gregory     Morgan  40.0
# 9682  user_09683      elizabeth38@example.net       Mark     Gibson  55.0
# 1551  user_01552       burnsshawn@example.org     Joseph  Rasmussen  22.0
#
#                  gender country             state_province               city  \
# ...

# %%
dataframes["movies"].sample(10)
# Out:
#        movie_id           title     content_type genre_primary  \
# 78   movie_0079   Mission Dream            Movie           War
# 856  movie_0857     Day Warrior  Stand-up Comedy         Sport
# 19   movie_0020      An Mystery        TV Series       Fantasy
# 399  movie_0400     Night Queen            Movie        Action
# 328  movie_0329  Battle Phoenix  Stand-up Comedy   Documentary
# 734  movie_0735   Princess Hero      Documentary       Fantasy
# 858  movie_0859   First Mission      Documentary        Action
# 185  movie_0186       Old House        TV Series        Comedy
# 357  movie_0358   Legend Secret        TV Series         Drama
# 128  movie_0129    Mission Fire  Stand-up Comedy        Sci-Fi
#
#     genre_secondary  release_year  duration_minutes rating language  \
# 78              NaN          2005             414.0   TV-G    Hindi
# 856        Thriller          2011              61.0      R  English
# ...

# %%
dataframes["reviews"].sample(10)
# Out:
#            review_id     user_id    movie_id  rating review_date device_type  \
# 7654   review_007655  user_02089  movie_0062       4  2025-12-20      Tablet
# 8144   review_008145  user_07967  movie_0419       4  2025-09-27      Laptop
# 855    review_000856  user_01498  movie_0338       3  2025-08-10      Tablet
# 5351   review_005352  user_02548  movie_0640       5  2025-01-05      Tablet
# 11726  review_011727  user_09360  movie_0097       1  2024-02-23      Tablet
# 13472  review_013473  user_05020  movie_0769       5  2025-02-25      Mobile
# 13697  review_013698  user_05793  movie_0863       3  2025-08-31      Laptop
# 10864  review_010865  user_04187  movie_0502       2  2025-06-13      Tablet
# 1342   review_001343  user_07000  movie_0997       4  2025-12-26    Smart TV
# 2033   review_002034  user_00702  movie_0562       4  2024-08-31      Tablet
#
#        is_verified_watch  helpful_votes  total_votes  \
# 7654                True            NaN          NaN
# ...

# %%
dataframes["recommendation_logs"].sample(10)
# Out:
#       recommendation_id     user_id    movie_id recommendation_date  \
# 41152        rec_041153  user_00969  movie_0708          2025-01-02
# 30312        rec_030313  user_07350  movie_0758          2025-04-13
# 19757        rec_019758  user_07026  movie_0127          2024-12-31
# 44605        rec_044606  user_02817  movie_0138          2025-01-01
# 32475        rec_032476  user_00138  movie_0983          2024-03-16
# 10025        rec_010026  user_07530  movie_0560          2025-04-23
# 41090        rec_041091  user_04140  movie_0758          2024-12-16
# 18600        rec_018601  user_01349  movie_0340          2025-10-05
# 41114        rec_041115  user_06639  movie_0319          2025-04-05
# 48134        rec_048135  user_03994  movie_0565          2025-02-27
#
#       recommendation_type  recommendation_score  was_clicked  \
# 41152        new_releases                 0.404        False
# 30312        personalized                   NaN        False
# ...

# %%
dataframes["search_logs"].sample(10)
# Out:
#            search_id     user_id         search_query search_date  \
# 9648   search_009649  user_04329  music documentaries  2024-04-01
# 12886  search_012887  user_09540     superhero movies  2025-07-01
# 18287  search_018288  user_04336         drama series  2025-12-11
# 11909  search_011910  user_01441       classic movies  2025-03-18
# 21060  search_021061  user_08130           true crime  2025-10-16
# 2508   search_002509  user_09109    netflix originals  2025-11-20
# 13064  search_013065  user_09097               sci-fi  2024-10-19
# 17516  search_017517  user_05536       classic movies  2024-04-20
# 15238  search_015239  user_08630           war movies  2024-10-30
# 217    search_000218  user_03667       animated shows  2024-04-21
#
#        results_returned  clicked_result_position device_type  \
# 9648                 75                      5.0      Mobile
# 12886                38                      NaN    Smart TV
# ...

# %%
dataframes["watch_history"].sample(10)
# Out:
#             session_id     user_id    movie_id  watch_date device_type  \
# 67862   session_067863  user_01322  movie_0632  2024-02-19      Laptop
# 87902   session_087903  user_02381  movie_0461  2024-12-06      Laptop
# 27486   session_027487  user_09253  movie_0844  2025-12-22    Smart TV
# 98907   session_098908  user_06194  movie_0090  2025-05-07     Desktop
# 1180    session_001181  user_01623  movie_0648  2025-04-09    Smart TV
# 80260   session_080261  user_01595  movie_0370  2025-06-09    Smart TV
# 77273   session_077274  user_05805  movie_0842  2024-10-29      Laptop
# 65442   session_065443  user_02312  movie_0476  2025-01-21      Mobile
# 104384  session_019095  user_05835  movie_0813  2025-11-25      Mobile
# 92252   session_092253  user_08187  movie_0545  2024-03-24     Desktop
#
#         watch_duration_minutes  progress_percentage     action   quality  \
# 67862                      NaN                 78.9     paused        HD
# ...

# %%
for name, df in dataframes.items():
    first_col = df.columns[0]
    dup_count = df[first_col].duplicated().sum()
    print(f"{name} duplicate counts (first column '{first_col}' only): {dup_count}")
# Out:
# recommendation_logs duplicate counts (first column 'recommendation_id' only): 2000
# reviews duplicate counts (first column 'review_id' only): 450
# users duplicate counts (first column 'user_id' only): 300
# test duplicate counts (first column 'test1' only): 0
# watch_history duplicate counts (first column 'session_id' only): 5000
# movies duplicate counts (first column 'movie_id' only): 40
# search_logs duplicate counts (first column 'search_id' only): 1500
